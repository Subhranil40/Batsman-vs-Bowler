# %%
import pandas as pd
import numpy as np
import math

# %%
delivery=pd.read_csv('IPL_Ball_by_Ball_2008_2022.csv')
delivery
# Out:
#              ID  innings  overs  ballnumber       batter          bowler  \
# 0       1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1       1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2       1312200        1      0           3   JC Buttler  Mohammed Shami
# 3       1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4       1312200        1      0           5  YBK Jaiswal  Mohammed Shami
# ...         ...      ...    ...         ...          ...             ...
# 225949   335982        2     14           5      P Kumar        I Sharma
# 225950   335982        2     14           6     SB Joshi        I Sharma
# 225951   335982        2     14           7      P Kumar        I Sharma
# 225952   335982        2     15           1     SB Joshi       LR Shukla
# 225953   335982        2     15           2     SB Joshi       LR Shukla
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# ...

# %%
mask1=delivery['batter']=='V Kohli'
mask2=delivery['bowler']=='JJ Bumrah'

# %%
bowlers=delivery['bowler'].unique().tolist()
bowlers.sort()    #to sort a list -- l.sort     sorted(l)
bowlers
# Out:
# ['A Ashish Reddy',
#  'A Badoni',
#  'A Chandila',
#  'A Choudhary',
#  'A Dananjaya',
#  'A Flintoff',
#  'A Kumble',
#  'A Mishra',
#  'A Mithun',
#  'A Nehra',
#  'A Nel',
#  'A Nortje',
#  'A Singh',
#  'A Symonds',
#  'A Uniyal',
#  'A Zampa',
#  'AA Chavan',
#  'AA Jhunjhunwala',
#  'AA Kazi',
#  'AA Noffke',
#  'AB Agarkar',
#  'AB Dinda',
#  'AB McDonald',
#  'AC Gilchrist',
#  'AC Thomas',
#  'AC Voges',
#  'AD Mascarenhas',
#  'AD Mathews',
#  'AD Russell',
#  'AF Milne',
#  'AG Murtaza',
#  'AJ Finch',
#  'AJ Tye',
#  'AK Markram',
#  'AL Menaria',
#  'AM Nayar',
#  'AM Rahane',
#  'AM Salvi',
#  'AN Ahmed',
#  'AP Dole',
#  'AR Patel',
#  'AS Joseph',
#  'AS Rajpoot',
#  'AS Raut',
#  'AS Roy',
#  'AU Rashid',
#  'AUK Pathan',
#  'Abdul Samad',
#  'Abdur Razzak',
#  'Abhishek Sharma',
#  'Akash Deep',
#  'Akash Singh',
#  'Aman Hakim Khan',
#  'Anand Rajan',
#  'Ankit Sharma',
#  'Ankit Soni',
#  'Anureet Singh',
#  'Arshdeep Singh',
#  'Avesh Khan',
#  'Azhar Mahmood',
# ...

# %%
new=delivery[mask1 & mask2]
new.sample(5)
# Out:
#              ID  innings  overs  ballnumber   batter     bowler  \
# 59714   1175362        2     13           2  V Kohli  JJ Bumrah
# 125129   733983        2      6           1  V Kohli  JJ Bumrah
# 13768   1304064        2     13           6  V Kohli  JJ Bumrah
# 72446   1136574        2     17           1  V Kohli  JJ Bumrah
# 149121   597999        1      4           2  V Kohli  JJ Bumrah
#
#            non-striker extra_type  batsman_run  extras_run  total_run  \
# 59714   AB de Villiers        NaN            1           0          1
# 125129        CH Gayle        NaN            0           0          0
# 13768       Anuj Rawat        NaN            3           0          3
# 72446        CR Woakes        NaN            1           0          1
# 149121        CH Gayle        NaN            4           0          4
#
#         non_boundary  isWicketDelivery player_out kind fielders_involved  \
# 59714              0                 0        NaN  NaN               NaN
# ...

# %% [markdown]
# ## Balls Faced

# %%
new.shape[0]
# Out:
# 95

# %% [markdown]
# ## Runs Scored

# %%
new['batsman_run'].sum()
# Out:
# 145

# %% [markdown]
# ## Strike Rate

# %%
round(new['batsman_run'].sum() / new.shape[0] *100,2)
# Out:
# 152.63

# %%
new.dropna(subset='player_out')
# Out:
#              ID  innings  overs  ballnumber   batter     bowler  \
# 32290   1254058        2     12           3  V Kohli  JJ Bumrah
# 45037   1216499        1     11           2  V Kohli  JJ Bumrah
# 59716   1175362        2     13           4  V Kohli  JJ Bumrah
# 149124   597999        1      4           5  V Kohli  JJ Bumrah
#
#            non-striker extra_type  batsman_run  extras_run  total_run  \
# 32290       GJ Maxwell        NaN            0           0          0
# 45037       D Padikkal        NaN            0           0          0
# 59716   AB de Villiers        NaN            0           0          0
# 149124        CH Gayle        NaN            0           0          0
#
#         non_boundary  isWicketDelivery player_out    kind fielders_involved  \
# 32290              0                 1    V Kohli     lbw               NaN
# 45037              0                 1    V Kohli  caught         SS Tiwary
# ...

# %% [markdown]
# ## No. of dismissals

# %%
new.dropna(subset='player_out')[new.dropna(subset='player_out')['kind']!='run out'].shape[0]
# Out:
# 4

# %% [markdown]
# ## No of 6's

# %%
new[new['batsman_run']==6].shape[0]
# Out:
# 5

# %% [markdown]
# ## No of 4's

# %%
new[new['batsman_run']==4].shape[0]
# Out:
# 16

# %% [markdown]
# ## No of dot's

# %%
new[new['batsman_run']==0].shape[0]
# Out:
# 34

# %% [markdown]
# # Function to get batsman vs bowler

# %%
batsmen=delivery['batter'].unique().tolist()
batsmen.sort()
batsmen
# Out:
# ['A Ashish Reddy',
#  'A Badoni',
#  'A Chandila',
#  'A Chopra',
#  'A Choudhary',
#  'A Dananjaya',
#  'A Flintoff',
#  'A Kumble',
#  'A Manohar',
#  'A Mishra',
#  'A Mithun',
#  'A Mukund',
#  'A Nehra',
#  'A Nortje',
#  'A Singh',
#  'A Symonds',
#  'A Tomar',
#  'A Uniyal',
#  'A Zampa',
#  'AA Bilakhia',
#  'AA Chavan',
#  'AA Jhunjhunwala',
#  'AA Noffke',
#  'AB Agarkar',
#  'AB Barath',
#  'AB Dinda',
#  'AB McDonald',
#  'AB de Villiers',
#  'AC Blizzard',
#  'AC Gilchrist',
#  'AC Thomas',
#  'AC Voges',
#  'AD Hales',
#  'AD Mascarenhas',
#  'AD Mathews',
#  'AD Nath',
#  'AD Russell',
#  'AF Milne',
#  'AG Murtaza',
#  'AG Paunikar',
#  'AJ Finch',
#  'AJ Turner',
#  'AJ Tye',
#  'AK Markram',
#  'AL Menaria',
#  'AM Nayar',
#  'AM Rahane',
#  'AN Ahmed',
#  'AN Ghosh',
#  'AP Dole',
#  'AP Majumdar',
#  'AP Tare',
#  'AR Bawne',
#  'AR Patel',
#  'AS Joseph',
#  'AS Rajpoot',
#  'AS Raut',
#  'AS Roy',
#  'AS Yadav',
#  'AT Carey',
#  'AT Rayudu',
#  'AUK Pathan',
# ...

# %%
def batter_vs_bowler(batsman,bowler):
    m1=delivery['batter']==batsman
    m2=delivery['bowler']==bowler
    final=delivery[m1 & m2]
    # print("No. of Balls: \t Runs Scored \t Strike Rate \t No.of Dismissals \t No. of 6's \t No. of 4's \t No. of dot's ")
    # print(f"{final.shape[0]} \t {final['batsman_run'].sum()} \t {round(final['batsman_run'].sum()/final.shape[0],2)} \t {final.dropna(subset='player_out')[new.dropna(subset='player_out')['kind']!='run out'].shape[0]} \t {final[final['batsman_run']==6].shape[0]} \t {final[final['batsman_run']==4].shape[0]} \t {final[final['batsman_run']==0].shape[0]}")
    # Assuming 'final' is a DataFrame with the necessary data
    l1=['No. of Balls','Runs Scored','Strike Rate','No. of Dismissals',"No. of 6's","No. of 4's","No. of dot's"]
    l2=[final.shape[0],final['batsman_run'].sum(),round(final['batsman_run'].sum()/final.shape[0]*100,2),final.dropna(subset='player_out')[final.dropna(subset='player_out')['kind'] != 'run out'].shape[0],final[final['batsman_run'] == 6].shape[0],final[final['batsman_run'] == 4].shape[0],final[final['batsman_run'] == 0].shape[0]]
    df=pd.DataFrame([l2],columns=l1)
    return df

# %%
batsman='V Kohli'
bowler='JJ Bumrah'
batter_vs_bowler(batsman,bowler)
# Out:
#    No. of Balls  Runs Scored  Strike Rate  No. of Dismissals  No. of 6's  \
# 0            95          145       152.63                  4           5
#
#    No. of 4's  No. of dot's
# 0          16            34
